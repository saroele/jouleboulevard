# %%
import opengrid as og
import pandas as pd
import tmpo

# %%
from opengrid.library import plotting

# %%
from joule import meta, filter_meta

# %%
filter_meta(Type='electricity')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [Type] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
meta.head()
# Out:
#                                                                MeterId  \
# SensorId
# 0e18c2764206a0044a537b4281d315a3  67C5F2A6-7516-4FEC-A038-620927B4ADA1
# 7fd4b068109b532b27520ba0b1ce9d27  E422C5EE-E201-45A3-8673-9B1CFBE9936B
# d4912b00c2baa517339b60dd7668b7b5  94C76BE3-DAEF-4055-A57F-AEB11A4DE476
# b39d7b29eb3e9f4667299c233366a801  E794D3C0-1F93-43B0-9CA3-4F84C48374D4
# 57785706313985e40caba6b5158f394d  34B3AFFB-7D64-484D-8665-CFCBAA07EE80
#
#                                        MeterName            Type Unit  \
# SensorId
# 0e18c2764206a0044a537b4281d315a3         Walvis3     electricity   wh
# 7fd4b068109b532b27520ba0b1ce9d27  Aardgas Flukso     natural gas    l
# d4912b00c2baa517339b60dd7668b7b5   Proximus_el_3     electricity   wh
# b39d7b29eb3e9f4667299c233366a801    Water Kelder  drinking water    l
# 57785706313985e40caba6b5158f394d  Gas Drankenkot     natural gas    l
#
#                                  RecordNumber     RecordName   DwellingType  \
# SensorId
# ...
